# %% [markdown]
# # Download Data

# %%
import nltk 
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
from nltk.corpus import twitter_samples

# %% [markdown]
# ## Read Data

# %%
positive_tweets=twitter_samples.strings('positive_tweets.json')
negative_tweets=twitter_samples.strings('negative_tweets.json')

# %% [markdown]
# ## Convert to pandas dataframe

# %%
import pandas as pd
pos_df = pd.DataFrame(positive_tweets, columns=["tweet"])
pos_df["target"] = 1
neg_df = pd.DataFrame(negative_tweets, columns=["tweet"])
neg_df["target"] = 0

# %%
# Combine both dataframes
df = pd.concat([pos_df, neg_df])
df.shape
# Out:
# (10000, 2)

# %%
df.sample(5)
# Out:
#                                                   tweet  target
# 4562                @izzy_sainz but too tired to eat :(       0
# 1726  @tracysharpy3 @Debbeedale Thank you for coming...       1
# 4338         @bridgetnichole_ have a fantastic night :)       1
# 2266                                  Missyou bishes :(       0
# 1408  My vault is expanding :D @Bethblog http://t.co...       1

# %% [markdown]
# ## Text Preprocessing

# %%
import string
import re

from nltk.corpus import stopwords 
nltk.download('stopwords')
stopwords_english = stopwords.words('english')

from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

from nltk.tokenize import TweetTokenizer

from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import html
def remove_special_chars(text):
    re1 = re.compile(r'  +')
    x1 = text.lower().replace('#39;', "'").replace('amp;', '&').replace('#146;', "'").replace(
        'nbsp;', ' ').replace('#36;', '$').replace('\\n', "\n").replace('quot;', "'").replace(
        '<br />', "\n").replace('\\"', '"').replace('<unk>', 'u_n').replace(' @.@ ', '.').replace(
        ' @-@ ', '-').replace('\\', ' \\ ')
    return re1.sub(' ', html.unescape(x1))

import unicodedata
def remove_non_ascii(text):
    """Remove non-ASCII characters from list of tokenized words"""
    return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')

# %%
def clean_tweets(tweet):
    #to_lowercase
    tweet=tweet.lower().strip()

    # remove special chars
    tweet=remove_special_chars(tweet)

    # remove_non_ascii
    tweet=remove_non_ascii(tweet)

    # remove stock market tickers like $GE
    tweet = re.sub(r'\$\w*', '', tweet)

    # remove old style retweet text "RT"
    tweet = re.sub(r'^RT[\s]+', '', tweet)

    # remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)

    #replace all interger occurrences in list of tokenized words with textual representation"""
    tweet=re.sub(r'\d+', '', tweet)

    # remove hashtags
    # only removing the hash # sign from the word
    tweet = re.sub(r'#', '', tweet)
    

    # tokenize tweets
    
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)
   
   
     
    tweets_clean = []   
    for word in tweet_tokens:
        if (word not in stopwords_english and # remove stopwords
              word not in string.punctuation): # remove punctuation
            #tweets_clean.append(word)
            stem_word = stemmer.stem(word) # stemming word

            #lemmatizer = WordNetLemmatizer()
            #lem_word=lemmatizer.lemmatize(word)
            #lem_word=lemmatizer.lemmatize(lem_word, pos='v') 
            tweets_clean.append(stem_word)
            

    return tweets_clean

# %%
df["tweet"] = df.tweet.apply(clean_tweets)
df.sample(5)
# Out:
#                                                   tweet  target
# 184      [followfriday, top, support, commun, week, :)]       1
# 1961  [love, much, believ, follow, pleas, follow, pl...       0
# 3966  [jacob, bday, got, tix, us, pari, omg, pleas, ...       1
# 722                                  [pleas, take, :-(]       0
# 3438                         [rain, need, go, away, :(]       0

# %% [markdown]
# ## Split the data into train and test set

# %%
from sklearn.model_selection import train_test_split
train_df,test_df = train_test_split(df, shuffle=True)
print("Shape of train and test set:", train_df.shape, test_df.shape)
# Out:
# Shape of train and test set: (7500, 2) (2500, 2)

# %% [markdown]
# ## Building frequency dictionary using training set

# %%
def build_frequency_dict(df):
    freqs = {}
    for i in range(len(df)):
        row = df.iloc[i]
        y = row.target
        for word in row.tweet :
            pair = (word, y)
            
            if pair in freqs:
              freqs[pair] += 1
            else:
              freqs[pair] = 1
            
    return freqs

# %%
freqs = build_frequency_dict(train_df)

# %%
freqs
# Out:
# {('thought', 0): 25,
#  ('today', 0): 77,
#  ('pizza', 0): 5,
#  ('day', 0): 106,
#  ('sadli', 0): 7,
#  ('none', 0): 4,
#  ('manag', 0): 11,
#  ('usual', 0): 5,
#  ('buy', 0): 13,
#  (':(', 0): 3423,
#  ('sunggyu', 0): 5,
#  ('fell', 0): 9,
#  ('stage', 0): 11,
#  ('hi', 1): 130,
#  ('everyon', 1): 45,
#  ('love', 1): 305,
#  ('u', 1): 128,
#  (':-)', 1): 523,
#  ('fish', 0): 1,
#  ('die', 0): 18,
#  ('feel', 0): 130,
#  ('like', 0): 159,
#  ('cri', 0): 38,
#  ('miss', 0): 227,
#  ('kindergarten', 0): 1,
#  ('kid', 0): 12,
#  ('im', 1): 38,
#  ('stream', 1): 11,
#  ('dude', 1): 4,
#  ('pull', 1): 1,
#  ('view', 1): 12,
#  ('time', 1): 106,
#  (':)', 1): 2678,
#  ('much', 0): 100,
#  ('new', 0): 33,
#  ('music', 0): 13,
#  ('cant', 0): 34,
#  ('record', 0): 6,
#  ('yet', 0): 26,
#  ('coz', 0): 3,
#  ('voic', 0): 6,
#  ('gone', 0): 20,
#  ('frustrat', 0): 4,
#  ('crap', 0): 2,
#  ('misplac', 0): 1,
#  ('phone', 0): 25,
#  ('good', 1): 171,
#  ('luck', 1): 23,
#  ('secret', 1): 7,
#  ('hwait', 1): 1,
#  ('four', 1): 3,
#  ("o'clock", 1): 1,
#  ('coffe', 1): 9,
#  ('habit', 1): 1,
#  ('den', 0): 1,
#  ('hey', 1): 60,
#  ('r', 1): 10,
#  ('camera', 1): 6,
#  ('cuz', 1): 2,
#  ('everytim', 1): 2,
#  ('look', 1): 110,
#  ('smile', 1): 38,
#  ('liveonstream', 1): 1,
#  ('everywher', 0): 4,
#  ('agre', 1): 14,
#  ('sarah', 1): 3,
#  ('phone', 1): 12,
#  ('realli', 1): 60,
#  ('busi', 1): 14,
#  ('give', 1): 35,
#  ('option', 1): 3,
#  ('c', 1): 6,
#  ('hello', 1): 46,
#  ('origin', 1): 4,
#  ('new', 1): 110,
#  ('merced', 1): 1,
#  ('hood', 1): 1,
#  ('badg', 1): 1,
#  ('guy', 1): 49,
#  ('blue', 1): 7,
#  ('eye', 1): 9,
#  (':d', 1): 483,
#  ('saw', 0): 16,
#  ('rted', 0): 2,
#  ('orig', 0): 1,
#  ('tweet', 0): 25,
#  ('starholicxx', 0): 1,
#  ('followfriday', 1): 19,
#  ('top', 1): 24,
#  ('influenc', 1): 13,
#  ('commun', 1): 24,
#  ('week', 1): 64,
#  ('ah', 0): 11,
#  ('bad', 0): 57,
#  ('social', 0): 1,
#  ('experi', 0): 2,
#  ('made', 0): 16,
#  ('greek', 0): 2,
#  ('tragedi', 0): 1,
#  ('cute', 0): 34,
#  ('song', 0): 21,
#  ('book', 0): 15,
#  ('trip', 0): 7,
#  ('crisi', 0): 1,
#  ('nope', 0): 3,
#  ('best', 0): 19,
#  ('place', 0): 15,
#  ('get', 0): 177,
#  ('first', 0): 18,
#  ('pre-ord', 0): 1,
#  ('amazon', 0): 4,
#  ('takfaham', 0): 1,
#  ('reject', 0): 7,
#  ('reason', 0): 6,
#  ('peopl', 0): 57,
#  ('deni', 0): 1,
#  ('realli', 0): 101,
#  ('stat', 1): 47,
#  ('day', 1): 183,
#  ('arriv', 1): 54,
#  ('follow', 1): 294,
#  ('unfollow', 1): 47,
#  ('via', 1): 51,
#  ('ohh', 0): 6,
#  ('yeah', 0): 34,
#  ('hope', 0): 74,
#  ('come', 0): 69,
#  ('back', 0): 91,
#  ('soon', 0): 35,
#  ('happi', 1): 160,
#  ('birthday', 1): 62,
#  ('iqbal', 1): 1,
#  ('wish', 1): 25,
#  ('best', 1): 50,
#  ('oh', 0): 73,
#  ('allow', 0): 8,
#  ('vote', 0): 5,
#  ('teen', 0): 4,
#  ('choic', 0): 3,
#  ('award', 0): 1,
#  ('said', 0): 22,
#  ("i'm", 0): 255,
#  ('area', 0): 4,
#  ('fair', 0): 10,
#  ('alreadi', 0): 43,
#  ('front', 0): 2,
#  ('row', 0): 3,
#  ('legit', 0): 1,
#  ('stadium', 0): 3,
#  ('lolliv', 0): 1,
#  ('where', 0): 1,
#  ('gf', 0): 3,
#  (':-(', 0): 367,
#  ('awww', 1): 7,
#  ('here', 1): 1,
#  ('quick', 1): 4,
#  ('workout', 1): 5,
#  ('boost', 1): 1,
#  ('arummzz', 1): 2,
#  ("let'", 1): 19,
#  ('go', 1): 120,
#  ('...', 1): 241,
#  ("i'll", 1): 70,
#  ('drive', 1): 9,
#  (':p', 1): 99,
#  ('travel', 1): 17,
#  ('yogyakarta', 1): 3,
#  ('jeep', 1): 3,
#  ('indonesia', 1): 3,
#  ('instamood', 1): 3,
#  ('mypapamyprid', 1): 2,
#  ('ourdaughtersourprid', 1): 4,
#  ('n', 1): 15,
#  ('encourag', 1): 3,
#  ('chang', 1): 13,
#  ('life', 1): 41,
#  ('sure', 1): 39,
#  ('..', 1): 99,
#  ('hahaha', 1): 12,
#  ('thu', 1): 1,
#  ('sneak', 1): 2,
#  ('away', 1): 12,
#  ('log', 1): 4,
#  ('niteflirt', 1): 1,
#  ('oh', 1): 31,
#  ('ye', 1): 52,
#  ('shirt', 1): 1,
#  ("they'r", 1): 11,
#  ('nice', 1): 70,
#  ('rofl', 1): 3,
#  ('old', 1): 7,
#  ('mint', 1): 1,
#  ("i'm", 1): 136,
#  ('rock', 1): 8,
#  ('sexi', 1): 5,
#  ('superdri', 1): 1,
#  ('tee', 1): 2,
#  ('right', 1): 36,
#  ('x', 1): 85,
#  ("he'", 0): 17,
#  ('alway', 0): 39,
#  ('gunna', 0): 1,
#  ('former', 0): 1,
#  ('leed', 0): 9,
#  ('junmyeon', 0): 1,
#  ('look', 0): 72,
#  ('ddi', 0): 1,
#  ('patti', 1): 1,
#  ('hay', 0): 7,
#  ('babi', 0): 33,
#  ('im', 0): 100,
#  ('updat', 1): 12,
#  ('finish', 1): 11,
#  ('pack', 1): 5,
#  ('fli', 1): 5,
#  ('stuck', 1): 3,
#  ('room', 1): 4,
#  ("we'r", 1): 19,
#  ('isol', 1): 1,
#  ('fa', 1): 1,
#  ('hi', 0): 29,
#  ('skulker', 0): 1,
#  ('check', 0): 17,
#  ('thread', 0): 1,
#  ('tire', 0): 37,
#  ('got', 0): 75,
#  ('good', 0): 80,
#  ('sleep', 0): 69,
#  ('that', 1): 11,
#  ('hope', 1): 106,
#  ('news', 1): 23,
#  ('dayz', 1): 1,
#  ('game', 1): 19,
#  ('preview', 1): 1,
#  ('reina', 1): 1,
#  ('sorri', 1): 18,
#  ('sound', 1): 15,
#  ('weird', 1): 5,
#  ('felt', 1): 2,
#  ('like', 1): 171,
#  ('cri', 1): 6,
#  ('drop', 0): 8,
#  ('dead', 0): 7,
#  ('fred', 0): 1,
#  ('use', 0): 32,
#  ('favorit', 0): 2,
#  ('movi', 0): 15,
#  ('wish', 0): 68,
#  ('justin', 0): 24,
#  ('blackberri', 0): 1,
#  ('shitti', 0): 1,
#  ('mobil', 0): 2,
#  ('povertyyouareevil', 0): 1,
#  ('time', 0): 130,
#  ('jhalak', 0): 1,
#  ('bore', 0): 19,
#  ('. ..', 0): 2,
#  ('concept', 0): 2,
#  ('bakwa', 0): 1,
#  ('old', 0): 12,
#  ('better', 0): 30,
#  ('interest', 0): 6,
#  ('. ...', 0): 1,
#  ('liv', 1): 2,
#  ('drake', 0): 1,
#  ('silent', 0): 1,
#  ("can't", 0): 136,
#  ('hear', 0): 29,
#  ("that'", 1): 57,
#  ('ok', 1): 32,
#  ('laiten', 1): 1,
#  ('interest', 1): 16,
#  ('would', 1): 65,
#  ('abl', 1): 6,
#  ('tell', 1): 20,
#  ('us', 1): 78,
#  ('card', 1): 7,
#  ('dj', 0): 2,
#  ('derek', 0): 3,
#  ('trend', 0): 6,
#  ('horribl', 0): 7,
#  ('found', 0): 11,
#  ('safe', 0): 5,
#  ('well', 0): 41,
#  ('girl', 0): 22,
#  ('say', 0): 52,
#  ('mean', 0): 29,
#  ('want', 0): 190,
#  ('man', 0): 23,
#  ('even', 0): 56,
#  ('know', 0): 94,
#  ('never', 1): 23,
#  ('success', 1): 4,
#  ('tri', 1): 33,
#  ('write', 1): 11,
#  ('someth', 1): 24,
#  ('dead', 1): 4,
#  ('peopl', 1): 36,
#  ('today', 1): 89,
#  ('need', 0): 92,
#  ('ice', 0): 31,
#  ('cream', 0): 29,
#  ('lolipop', 0): 1,
#  ('chocol', 0): 7,
#  ('kebab', 0): 1,
#  ('klappertart', 0): 1,
#  ('cake', 0): 8,
#  ('moodbost', 0): 2,
#  ('zayniscomingbackonjuli', 0): 15,
#  ('funni', 0): 5,
#  ('cuti', 1): 6,
#  ('b', 0): 10,
#  ('rude', 0): 7,
#  ('nhi', 1): 2,
#  ('tha', 1): 4,
#  ('offic', 1): 8,
#  ('work', 1): 90,
#  ('bahot', 1): 1,
#  ('baje', 1): 1,
#  ('raat', 1): 1,
#  ('ko', 1): 3,
#  ('liya', 1): 1,
#  ('hath', 1): 1,
#  ('creat', 1): 7,
#  ('ghant', 1): 1,
#  ('itna', 1): 1,
#  ('bana', 1): 1,
#  ('paya', 1): 1,
#  ('dad', 0): 8,
#  ('sorri', 0): 116,
#  ('moment', 0): 11,
#  ('...', 0): 256,
#  ('see', 0): 114,
#  ('krystoria', 0): 1,
#  ('porsch', 1): 1,
#  ('paddock', 1): 1,
#  ('budapestgp', 1): 1,
#  ('found', 1): 11,
#  ('johnyherbert', 1): 1,
#  ('roll', 1): 5,
#  ('weekend', 1): 60,
#  ('porschesupercup', 1): 1,
#  ('youuu', 0): 5,
#  ('tmrw', 1): 3,
#  ('lmao', 1): 3,
#  ('berni', 1): 1,
#  ("i'll", 0): 31,
#  ('rumbl', 0): 1,
#  ('da', 0): 5,
#  ('kumbl', 0): 1,
#  ('bc', 0): 33,
#  ("that'", 0): 45,
#  ('tri', 0): 54,
#  ('keep', 0): 23,
#  ('hous', 0): 11,
#  ('truckload', 0): 1,
#  ('favour', 0): 2,
#  ('fucjikg', 0): 1,
#  ('disgust', 0): 5,
#  ('bare', 0): 5,
#  ('boob', 0): 1,
#  ('late', 1): 8,
#  ('lunch', 1): 3,
#  ('kfc', 1): 2,
#  ('univers', 1): 2,
#  ('santo', 1): 1,
#  ('toma', 1): 1,
#  ('yeah', 1): 30,
#  ('classi', 1): 1,
#  ("i'v", 1): 25,
#  ('seen', 1): 5,
#  ('attach', 1): 1,
#  ('sort', 1): 5,
#  ('save', 1): 8,
#  ('equip', 1): 1,
#  ('bed', 1): 11,
#  ('fix', 1): 5,
#  ('follow', 0): 196,
#  ('thank', 0): 81,
#  ('pleas', 0): 209,
#  ('damn', 0): 21,
#  ('forgot', 0): 9,
#  ('hot', 0): 12,
#  ('fun', 0): 23,
#  ('snapchat', 0): 57,
#  ('jennyjean', 0): 1,
#  ('hornykik', 0): 14,
#  ('eboni', 0): 2,
#  ('trade', 0): 3,
#  ('model', 0): 9,
#  ('elfindelmundo', 0): 2,
#  ('webcamsex', 0): 3,
#  ('lol', 0): 30,
#  ('ye', 0): 36,
#  ('kaslkdja', 0): 1,
#  ('final', 0): 28,
#  ('week', 0): 48,
#  ('sweet', 1): 14,
#  ('sunburn', 1): 1,
#  ('peel', 1): 2,
#  ('mingm', 0): 1,
#  ('zayn', 1): 3,
#  ('crazi', 0): 8,
#  ('love', 0): 120,
#  ('(:', 0): 5,
#  ('everyth', 0): 12,
#  ('remind', 0): 2,
#  ('u', 0): 162,
#  ('aw', 0): 33,
#  ('shame', 0): 9,
#  ("we'll", 0): 6,
#  ('mager', 0): 1,
#  ('wi', 0): 1,
#  ('happen', 0): 42,
#  ('ahah', 1): 1,
#  ('thank', 1): 457,
#  ('candi', 1): 2,
#  ('axio', 1): 1,
#  ('remind', 1): 5,
#  ('lot', 1): 64,
#  ('white', 1): 2,
#  ('rabbit', 1): 1,
#  ('longer', 0): 10,
#  ('toast', 0): 1,
#  ('nose', 0): 5,
#  ('forehead', 0): 4,
#  ('peel', 0): 1,
#  ('morn', 1): 86,
#  ('friday', 1): 83,
#  ('great', 1): 146,
#  ('start', 1): 47,
#  ('larri', 1): 2,
#  ('real', 1): 17,
#  ('pleas', 1): 73,
#  ('follback', 1): 16,
#  ('ur', 1): 29,
#  ('voic', 1): 2,
#  ('heheheh', 1): 1,
#  ('sad', 0): 84,
#  ('return', 0): 6,
#  ('holiday', 0): 18,
#  ('find', 0): 39,
#  ('radio', 0): 4,
#  ('morn', 0): 25,
#  ('drive', 0): 11,
#  ('guy', 0): 44,
#  ('famou', 0): 5,
#  ('bowl', 0): 1,
#  ('barney', 0): 1,
#  ('stu', 0): 1,
#  ('deactiv', 0): 6,
#  ('promot', 1): 5,
#  ('cake', 1): 7,
#  ('swear', 1): 3,
#  ('walk', 1): 9,
#  ('nail', 1): 2,
#  ('three', 1): 7,
#  ('word', 1): 14,
#  ('rohit', 1): 1,
#  ('non-filipina', 1): 1,
#  ('fan', 1): 21,
#  ('ejayst', 1): 1,
#  ('unit', 1): 3,
#  ('state', 1): 1,
#  ('haha', 1): 43,
#  ('pegel', 1): 1,
#  ('lemess', 1): 1,
#  ('well', 1): 65,
#  ('done', 1): 43,
#  ('carri', 1): 1,
#  ('listen', 1): 12,
#  ('buddi', 1): 5,
#  ('wanna', 1): 23,
#  ('play', 1): 32,
#  ('stomach', 0): 6,
#  ('kill', 0): 17,
#  ('dang', 0): 2,
#  ('start', 0): 38,
#  ('next', 0): 31,
#  ('work', 0): 92,
#  ('rain', 0): 32,
#  ('go', 0): 159,
#  ('away', 0): 21,
#  ('liam', 1): 7,
#  ('year', 1): 25,
#  ('small', 0): 8,
#  ('ladi', 0): 3,
#  ('walk', 0): 6,
#  ('sore', 0): 6,
#  ('keep', 1): 54,
#  ('come', 1): 47,
#  ('list', 1): 12,
#  ('someon', 1): 23,
#  ('els', 1): 9,
#  ('mention', 1): 17,
#  ('persona', 1): 1,
#  ('ill', 1): 5,
#  ('child', 1): 2,
#  ('saturday', 0): 8,
#  ('gut', 0): 11,
#  ('pride', 0): 1,
#  ('shannon', 1): 1,
#  ('woohoo', 1): 3,
#  ('wsalelov', 1): 13,
#  ('bro', 1): 19,
#  ('want', 1): 64,
#  ('amaz', 1): 39,
#  ('kurta', 1): 3,
#  ('rakhi', 1): 1,
#  ('omg', 0): 52,
#  ('yup', 1): 5,
#  ('happen', 1): 12,
#  ('everywher', 1): 2,
#  ('cant', 1): 11,
#  ('debat', 1): 2,
#  ('name', 1): 14,
#  ('call', 1): 30,
#  ('add', 0): 19,
#  ('kik', 0): 48,
#  ('mork', 0): 1,
#  ('kikgirl', 0): 11,
#  ('kikhorni', 0): 7,
#  ('addmeonsnapchat', 0): 2,
#  ('premiostumundo', 0): 2,
#  ('hotspotwithdanri', 0): 1,
#  ('omw', 0): 1,
#  ('coldplay', 1): 1,
#  ('song', 1): 17,
#  ('playlist', 1): 5,
#  ('favorit', 1): 11,
#  ('scientist', 1): 1,
#  ('yellow', 1): 1,
#  ('atla', 1): 1,
#  ('home', 0): 48,
#  ('sinc', 0): 32,
#  ('belieb', 0): 2,
#  ('forev', 0): 8,
#  ('hold', 0): 5,
#  ('special', 0): 2,
#  ('heart', 0): 23,
#  ('gonna', 0): 38,
#  ('germani', 0): 3,
#  ('find', 1): 15,
#  ('one', 1): 100,
#  ('alreadi', 1): 19,
#  ('get', 1): 154,
#  ('better', 1): 33,
#  ('quickli', 1): 3,
#  ("i'v", 0): 58,
#  ('wrong', 0): 26,
#  ('powerpoint', 0): 1,
#  ('present', 0): 5,
#  ('expect', 0): 5,
#  ('diner', 0): 1,
#  ('no-no', 0): 1,
#  ('either', 0): 10,
#  ('scoup', 0): 2,
#  ('bakit', 0): 4,
#  ("t'would", 1): 1,
#  ('tweetup', 1): 1,
#  ('without', 1): 9,
#  ('book', 1): 18,
#  ('rest', 1): 12,
#  ('assur', 1): 2,
#  ('welsh', 1): 1,
#  ('wale', 1): 3,
#  ('yippe', 1): 1,
#  ('shoe', 0): 1,
#  ('ship', 0): 6,
#  ('take', 0): 37,
#  ('arriv', 0): 3,
#  ('way', 0): 29,
#  ('smadvow', 0): 1,
#  ('lgbt', 0): 3,
#  ('photo', 0): 12,
#  ('free', 0): 15,
#  ('hotti', 0): 3,
#  ('wanna', 0): 73,
#  ('meet', 0): 22,
#  ('sooo', 0): 13,
#  ('concert', 1): 19,
#  ('let', 1): 51,
#  ('know', 1): 105,
#  ('citi', 1): 22,
#  ('countri', 1): 18,
#  ('chri', 0): 4,
#  ('uni', 1): 1,
#  ('talent', 1): 4,
#  ('bam', 1): 31,
#  ('bestfriend', 1): 36,
#  ('see', 1): 132,
#  ('warsaw', 1): 31,
#  ('xd', 0): 5,
#  ('ship', 1): 6,
#  ('got', 1): 54,
#  ('order', 1): 8,
#  ('believ', 0): 31,
#  ('x', 0): 55,
#  ('enjoy', 1): 58,
#  ('tango', 1): 1,
#  ('geneva', 0): 1,
#  ('england', 0): 4,
#  ('aint', 0): 7,
#  ('half', 0): 9,
#  ('sun', 0): 8,
#  ('k', 1): 10,
#  ('noth', 1): 12,
#  ('asham', 1): 1,
#  ('least', 1): 12,
#  ('duke', 1): 2,
#  ('earl', 1): 1,
#  ('exactli', 0): 4,
#  ('co', 0): 6,
#  ('would', 0): 50,
#  ('entertain', 0): 1,
#  ('tbh', 0): 9,
#  ('hey', 0): 21,
#  ('rememb', 0): 9,
#  ('typa', 0): 2,
#  ('weather', 0): 23,
#  ('brother', 1): 4,
#  ('steven', 0): 2,
#  ('listen', 0): 12,
#  ('snapchat', 1): 31,
#  ('lynettelow', 1): 1,
#  ('kikmenow', 1): 2,
#  ('snapm', 1): 2,
#  ('hot', 1): 18,
#  ('amazon', 1): 1,
#  ('kikmeguy', 1): 2,
#  ('think', 0): 56,
#  ('could', 0): 47,
#  ('last', 0): 50,
#  ('togeth', 0): 6,
#  ('hate', 0): 44,
#  ('transfer', 0): 3,
#  ('window', 0): 3,
#  ('bring', 1): 14,
#  ('attent', 1): 3,
#  ('question', 1): 13,
#  ('tb', 1): 2,
#  ('hahah', 0): 6,
#  ('boy', 0): 14,
#  ('came', 0): 13,
#  ('milkshak', 0): 1,
#  ('hahahah', 0): 3,
#  ('holi', 0): 2,
#  ('shit', 0): 26,
#  ('comfort', 0): 3,
#  ('kyli', 0): 3,
#  ('jenner', 0): 1,
#  ('cloth', 0): 5,
#  ('wonder', 0): 7,
#  ('okay', 0): 28,
#  ('hair', 0): 17,
#  ('long', 0): 27,
#  ('thought', 1): 24,
#  ('might', 1): 24,
#  ('saw', 1): 13,
#  ('vers', 1): 1,
#  ('butterfli', 1): 1,
#  ('part', 1): 14,
#  ('bonu', 1): 2,
#  ('met', 0): 5,
#  ('kind', 0): 7,
#  ('classmat', 0): 1,
#  ('set', 0): 10,
#  ('friend', 0): 33,
#  ('dont', 0): 40,
#  ('bestfriend', 0): 5,
#  ("sculptor'", 1): 1,
#  ('pillar', 1): 2,
#  ('avail', 1): 9,
#  ('store', 1): 12,
#  ('thing', 1): 51,
#  ('releas', 1): 10,
#  ('ti', 1): 1,
#  ('dota', 1): 2,
#  ('mixtur', 0): 1,
#  ('proud', 0): 6,
#  ('far', 0): 13,
#  ("they'v", 0): 3,
#  ('also', 0): 17,
#  ('c', 0): 5,
#  ('w', 0): 18,
#  ('rn', 0): 15,
#  ('dear', 0): 9,
#  ('discount', 0): 1,
#  ('though', 0): 39,
#  ('consum', 0): 1,
#  ('awww', 0): 17,
#  ('imper', 0): 1,
#  ('trmdhesit', 0): 1,
#  ('gross', 0): 5,
#  ('envi', 0): 1,
#  ('pictur', 0): 14,
#  ('laura', 0): 4,
#  ('taylor', 0): 2,
#  ('lana', 0): 2,
#  ('etc', 0): 2,
#  ("they'r", 0): 11,
#  ('lucki', 0): 11,
#  ('breakfast', 1): 2,
#  ('champion', 1): 1,
#  ('okay', 1): 28,
#  ('littl', 1): 24,
#  ('featur', 1): 4,
#  ('yujo-cosplay', 1): 1,
#  ('cosplay', 1): 4,
#  ('luxembourg', 1): 1,
#  ('messag', 1): 8,
#  ('nicola', 1): 1,
#  ('forward', 1): 23,
#  ('brighten', 1): 1,
#  ('helen', 1): 3,
#  ('earli', 0): 9,
#  ('drew', 1): 2,
#  ('alek', 1): 1,
#  ('nightmar', 0): 5,
#  ('show', 0): 18,
#  ('weird', 0): 10,
#  ('leav', 0): 30,
#  ('might', 0): 8,
#  ('give', 0): 32,
#  ('pale', 0): 1,
#  ('imit', 0): 1,
#  ('goodnight', 0): 1,
#  ('messag', 0): 6,
#  ('haaa', 1): 1,
#  ('miss', 1): 18,
#  ('watch', 0): 52,
#  ('topgear', 0): 1,
#  ('episod', 0): 9,
#  ('end', 0): 23,
#  ('luck', 0): 6,
#  ('move', 0): 9,
#  ('sydney', 0): 1,
#  ('everyon', 0): 25,
#  ('decid', 0): 6,
#  ('hahaha', 0): 10,
#  ('pray', 0): 10,
#  ('video', 1): 28,
#  ('readi', 1): 21,
#  ('tomorrow', 1): 28,
#  ('sleep', 1): 31,
#  ('peac', 1): 6,
#  ('tonight', 1): 16,
#  ('goodnight', 1): 19,
#  ('ubericecream', 0): 12,
#  ('avail', 0): 12,
#  ('retweet', 1): 31,
#  ('afternoon', 1): 7,
#  ('nooo', 0): 15,
#  ('sogok', 0): 1,
#  ('thankyou', 1): 11,
#  ('pretti', 1): 13,
#  ('music', 1): 16,
#  ('check', 1): 39,
#  ('amaz', 0): 14,
#  ('meadowhal', 0): 1,
#  ('actual', 0): 20,
#  ('unfortun', 0): 14,
#  ('weekend', 0): 18,
#  ('unknown', 0): 2,
#  ('yay', 1): 10,
#  ("weekend'", 1): 1,
#  ('punt', 1): 1,
#  ('horserac', 1): 1,
#  ('hors', 1): 2,
#  ('bet', 1): 5,
#  ('horseracingtip', 1): 1,
#  ('jabongatpumaurbanstamped', 1): 3,
#  ('an', 1): 2,
#  ('fault', 0): 3,
#  ('sweedi', 0): 1,
#  ('eyyah', 0): 1,
#  ('utd', 0): 2,
#  ('born', 0): 1,
#  ('build', 1): 6,
#  ('hous', 1): 5,
#  ('around', 0): 15,
#  ('tom', 0): 4,
#  ('congratul', 1): 13,
#  ('sat', 1): 1,
#  ('rd', 1): 4,
#  ('honorari', 1): 1,
#  ('degre', 1): 3,
#  ('alac', 1): 1,
#  ('holiday', 1): 8,
#  ('irk', 0): 1,
#  ('retweet', 0): 3,
#  ('pleaaas', 0): 1,
#  ('everyth', 1): 12,
#  ('actuallyand', 1): 1,
#  ('someon', 0): 46,
#  ('tooo', 0): 1,
#  ('..', 0): 82,
#  ('whyyi', 0): 7,
#  ('pleasur', 1): 11,
#  ('alway', 1): 54,
#  ('tonight', 0): 17,
#  ('photoshooot', 0): 1,
#  ('peter', 1): 1,
#  ('yo', 0): 4,
#  ('dude', 0): 11,
#  ('fanci', 0): 2,
#  ('help', 0): 37,
#  ('fan', 0): 16,
#  ('grow', 0): 1,
#  ('yt', 0): 2,
#  ('channel', 0): 5,
#  ('purchas', 0): 1,
#  ('elgato', 0): 1,
#  ('read', 1): 23,
#  ('review', 1): 7,
#  ('awesom', 1): 28,
#  ('suggest', 1): 5,
#  ('rude', 1): 3,
#  ('say', 1): 45,
#  ('help', 1): 28,
#  ('me.so', 1): 1,
#  ('other', 1): 9,
#  ('tho', 1): 10,
#  ('idea', 1): 20,
#  ('night', 1): 45,
#  ('f', 1): 3,
#  ('vine', 0): 2,
#  ('luke', 0): 5,
#  ('clip', 0): 1,
#  ('year', 0): 37,
#  ('hola', 1): 1,
#  ('juan', 1): 1,
#  ('send', 1): 18,
#  ('big', 1): 25,
#  ('houston', 1): 1,
#  ('tx', 1): 2,
#  ('jenni', 1): 1,
#  ('famili', 1): 13,
#  ("year'", 1): 2,
#  ('stumbl', 1): 1,
#  ('upon', 1): 1,
#  ('sigh', 0): 12,
#  ('make', 0): 83,
#  ('mike', 0): 1,
#  ('rm', 1): 1,
#  ('still', 1): 42,
#  ('negooo', 1): 1,
#  ('male', 1): 1,
#  ('wait', 1): 45,
#  ('nude', 1): 2,
#  ('eye', 0): 11,
#  ('apart', 0): 6,
#  ('bless', 1): 11,
#  ('shorthair', 1): 1,
#  ('oscar', 1): 1,
#  ('notic', 0): 17,
#  ('h', 0): 7,
#  ('bad', 1): 15,
#  ('chanhun', 1): 1,
#  ('individu', 1): 2,
#  ('photoshoot', 1): 1,
#  ('afteral', 1): 1,
#  ('dci', 0): 1,
#  ('school', 0): 27,
#  ('without', 0): 18,
#  ('bracelet', 0): 3,
#  ('odd', 0): 3,
#  ('al', 0): 4,
#  ('kati', 0): 3,
#  ('zaz', 0): 1,
#  ('ami', 0): 2,
#  ('lot', 0): 23,
#  ('act', 1): 7,
#  ('mischiev', 1): 1,
#  ('etl', 1): 1,
#  ('layer', 1): 1,
#  ('in-hous', 1): 1,
#  ('wareh', 1): 1,
#  ('app', 1): 14,
#  ('katamari', 1): 1,
#  ('impli', 1): 1,
#  ('dream', 1): 16,
#  ('sign', 1): 10,
#  ('along', 1): 5,
#  ('unknown', 1): 1,
#  ('roomi', 1): 1,
#  ('tittheir', 0): 1,
#  ('fuck', 0): 40,
#  ('kikm', 0): 6,
#  ('likelik', 0): 3,
#  ('indiemus', 0): 10,
#  ('summer', 0): 15,
#  ('wua', 0): 1,
#  ('kind', 1): 22,
#  ('unappreci', 1): 1,
#  ('even', 1): 25,
#  ('site', 1): 9,
#  ('graciou', 1): 1,
#  ('feedback', 1): 7,
#  ('smile', 0): 7,
#  ('chem', 0): 2,
#  ('lt', 0): 1,
#  ('nice', 0): 15,
#  ('mate', 1): 6,
#  ('much', 1): 66,
#  ('appreci', 1): 25,
#  ('reynold', 0): 1,
#  ('dessert', 0): 1,
#  ('done', 0): 19,
#  ('season', 0): 9,
#  ('enter', 1): 6,
#  ('win', 1): 12,
#  ('huge', 1): 8,
#  ('packag', 1): 3,
#  ('two', 0): 15,
#  ('pabebegirl', 0): 1,
#  ('pabeb', 0): 2,
#  ('video', 0): 13,
#  ('problemmm', 1): 1,
#  ('sunday', 1): 8,
#  ('cours', 0): 5,
#  ('spree', 0): 3,
#  ('hello', 0): 10,
#  ('info', 0): 4,
#  ('possibl', 0): 7,
#  ('jonatha', 0): 3,
#  ('close', 0): 14,
#  ('join', 0): 5,
#  ('beti', 0): 3,
#  ('gosh', 0): 6,
#  ('__', 0): 2,
#  ('fri', 0): 6,
#  ('noodl', 0): 1,
#  ('stop', 0): 31,
#  ('sell', 0): 5,
#  ('ap', 0): 2,
#  ('anymor', 0): 13,
#  ('dm', 0): 18,
#  ('thing', 0): 41,
#  ('prefer', 0): 3,
#  ('kitten', 0): 1,
#  ('puppi', 0): 3,
#  ('note', 1): 5,
#  ('almost', 1): 8,
#  ('watch', 1): 35,
#  ('muna', 1): 1,
#  ('na', 1): 6,
#  ('magstart', 1): 1,
#  ('ang', 1): 1,
#  ('twitter', 1): 23,
#  ('parti', 1): 6,
#  ('salut', 1): 3,
#  ('yeheyi', 1): 1,
#  ('pinya', 1): 1,
#  ('whoooah', 1): 1,
#  ('apolog', 0): 2,
#  ('australia', 0): 3,
#  ('welcom', 1): 56,
#  ('respons', 1): 7,
#  ('first', 1): 35,
#  ('hour', 1): 21,
#  ('delight', 1): 5,
#  ('comment', 1): 4,
#  ('next', 1): 36,
#  ('z', 0): 3,
#  ('pick', 1): 10,
#  ('number', 1): 8,
#  ('retail', 1): 4,
#  ('stock', 1): 2,
#  ('product', 1): 10,
#  ('car', 0): 13,
#  ('suspems', 0): 1,
#  ('cope', 0): 2,
#  ('offroad', 0): 1,
#  ('adventur', 0): 1,
#  ('there', 0): 4,
#  ('harvest', 0): 1,
#  ('machineri', 0): 1,
#  ('left', 0): 21,
#  ('inapropri', 0): 1,
#  ('weav', 0): 2,
#  ('potato', 1): 1,
#  ('garden', 1): 6,
#  ('hundr', 1): 1,
#  ('dig', 1): 1,
#  ('wow', 1): 13,
#  ('tattoo', 1): 2,
#  ('ivypowel', 1): 1,
#  ('kik', 1): 14,
#  ('chat', 1): 7,
#  ('xxx', 1): 10,
#  ('kikmeboy', 1): 6,
#  ('newmus', 1): 1,
#  ('sexchat', 1): 1,
#  ('visit', 1): 26,
#  ('blog', 1): 23,
#  ('sooo', 1): 5,
#  ('grade', 1): 4,
#  ('lock', 0): 1,
#  ('night', 0): 32,
#  ...}

# %% [markdown]
# ## we extract three features from the frequencies.
# 1-Bias: 1 for all tweets
#
# 2- positive frequencies count
#
# 3- negative frequencies count

# %%
import numpy as np
def extract_features(tweet, freqs):
    # Initialize a zeros array with size 3
    feats = np.zeros(3, dtype=int)
    # set bias to 1
    feats[0] = 1
    
    for word in tweet :
        # Set positive frequencies count
        if (word, 1) in freqs.keys(): feats[1] += freqs[(word, 1)]
        # Set negative frequencies count
        if (word, 0) in freqs.keys(): feats[2] += freqs[(word, 0)]
    
    assert(feats.shape == (3,))
    return feats

# %%
# Test extract_features function
sample = df.tweet.iloc[10]
sample_feats = extract_features(sample, freqs)
print("tweet:", sample)
print("features:", sample_feats)
# Out:
# tweet: ['followfriday', 'top', 'influenc', 'commun', 'week', ':)']
# features: [   1 2822   55]

# %% [markdown]
# ## extract features from train and test set

# %%
from functools import partial
from sklearn.linear_model import LogisticRegression
X_train = train_df.tweet.apply(partial(extract_features, freqs=freqs))
X_train = np.stack(X_train.values)
y_train = train_df.target.values

X_test = test_df.tweet.apply(partial(extract_features, freqs=freqs))
X_test = np.stack(X_test.values)
y_test = test_df.target.values

print(X_train.shape, y_train.shape,X_test.shape, y_test.shape)
# Out:
# (7500, 3) (7500,) (2500, 3) (2500,)

# %%
X_train
# Out:
# array([[   1,  314, 3676],
#        [   1,    2, 3448],
#        [   1, 1131,  336],
#        ...,
#        [   1,   26, 3667],
#        [   1, 3062,  349],
#        [   1, 2832,   74]])

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
print("Train accuracy:", clf.score(X_train, y_train))
# Out:
# Train accuracy: 0.9902666666666666

# %%
y_pred = clf.predict(X_test)
from sklearn.metrics import accuracy_score
print("test accuracy:", accuracy_score(y_test,y_pred))
# Out:
# test accuracy: 0.9904

# %% [markdown]
# ## test our model with new samples

# %%
def test(tweet):
    sent =  clean_tweets(tweet)
    test_feats = extract_features(tweet, freqs)
    y_pred = clf.predict(test_feats.reshape(1,-1))
    if y_pred[0] == 1: return "positive"
    elif y_pred[0] == 0: return "negative"
    else: return None

# %%
test("@seanactual You mean you're not offering? :(")
# Out:
# 'negative'

# %%
test("This movie is really good")
# Out:
# 'positive'

# %% [markdown]
# END
